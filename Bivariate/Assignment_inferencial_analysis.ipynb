# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
dataset=pd.read_csv("Placement (1).csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
##salary filed has NaN values..
## For Data preprocessing, separate Numerical and categorical column

# %%
## For Data preprocessing, separate Numerical and categorical column

quan=[]
qual=[]
for column_name in dataset.columns:
    if dataset[column_name].dtypes=='O':
        qual.append(column_name)
    else:
        quan.append(column_name)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       NaN
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       NaN
#
# [215 rows x 7 columns]

# %%
dataset[qual]
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %% [markdown]
# ## 1. Replace NaN values in Salary field

# %%
### salary column has NaN...
#### Replace it with Mean, Median or Mode by Simple Imputer class...

from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=pd.NA, strategy='mean')
quan_dataset=imputer.fit_transform(dataset[quan])
quan_dataset
# Out:
# array([[1.00000000e+00, 6.70000000e+01, 9.10000000e+01, ...,
#         5.50000000e+01, 5.88000000e+01, 2.70000000e+05],
#        [2.00000000e+00, 7.93300000e+01, 7.83300000e+01, ...,
#         8.65000000e+01, 6.62800000e+01, 2.00000000e+05],
#        [3.00000000e+00, 6.50000000e+01, 6.80000000e+01, ...,
#         7.50000000e+01, 5.78000000e+01, 2.50000000e+05],
#        ...,
#        [2.13000000e+02, 6.70000000e+01, 6.70000000e+01, ...,
#         5.90000000e+01, 6.97200000e+01, 2.95000000e+05],
#        [2.14000000e+02, 7.40000000e+01, 6.60000000e+01, ...,
#         7.00000000e+01, 6.02300000e+01, 2.04000000e+05],
#        [2.15000000e+02, 6.20000000e+01, 5.80000000e+01, ...,
#         8.90000000e+01, 6.02200000e+01, 2.88655405e+05]])

# %%
quan_table=pd.DataFrame(data=quan_dataset,columns=quan)

# %%
quan_table
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000
# ..     ...    ...    ...       ...      ...    ...            ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405
#
# [215 rows x 7 columns]

# %%
quan_table.isnull().sum()
#quan_table.isna().sum()
# Out:
# sl_no       0
# ssc_p       0
# hsc_p       0
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64

# %%
## no null values in quan columns.. so we can create a table with that features...

qual_table=pd.DataFrame(data=dataset[qual],columns=qual)
qual_table
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
qual_table.isnull().sum()
#qual_table.isna().sum()
# Out:
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# combining qual and quan tables

preprocessed_ds=pd.concat([quan_table,qual_table],axis=1,join="inner")
preprocessed_ds
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %% [markdown]
# # 2.  How many of them are not placed

# %%
n=(preprocessed_ds["status"]=="Not Placed").sum()
n
# Out:
# np.int64(67)

# %% [markdown]
# # 3.  Find the reason for non placement from the dataset

# %%
## Not placement due to Null values...

# %% [markdown]
# ## 4. What kind of relation between mba_p and salary???

# %%
# What kind of relation between mba_p and salary???

quan_table.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.051550
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.023571
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.054506
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.014148
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.152829
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.146324
# salary    0.051550  0.023571  0.054506 -0.014148  0.152829  0.146324  1.000000

# %%
# Conclusion
# relation between mba_p and salary: 0.146324
# Low degree postive correaltion since R= +Low or <0.54

# %% [markdown]
# ## 5. Which specialization is getting minimum salary?

# %%
min_salary = dataset["salary"].min()

specialisation_min_salary_dataset= dataset[dataset["salary"] == min_salary]["specialisation"]

specialisation_min_salary_dataset
# Out:
# 1      Mkt&Fin
# 15     Mkt&Fin
# 44     Mkt&Fin
# 50      Mkt&HR
# 107     Mkt&HR
# 135     Mkt&HR
# Name: specialisation, dtype: object

# %% [markdown]
# ## 6. How many of them getting above 500000 salary?

# %%
dataset[quan_table["salary"]>=500000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 174    175      M  73.24   Others  50.83   Others   Science     64.27
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 77    Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 163   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 174   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0
# ...

# %% [markdown]
# ## 7. Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
# Analysis of variance- ANAVO etest_p, mba_p

# H0(Null hypo)- there is no significance difference betn etest, mba_p
# H1- there is significance diff betn etest and mba_p
# if p<.05 reject Null Hypothesis and accept Alternative hypothesis, 
    # else, accept Null hypothesis and reject Alternative hypothesis

# %%
import scipy.stats as stats
stats.f_oneway(quan_table["etest_p"],quan_table["mba_p"])
# Out:
# F_onewayResult(statistic=np.float64(98.64487057324706), pvalue=np.float64(4.672547689134635e-21))

# %%
## if p>.05, Accept Null hypothesis and reject Alternate hypothesis


## Conclusion: pvalue=np.float64(4.672547689134635e-21, which is less than .05. so Reject Null Hypothesis and Accept Alternate Hypothesis.
## Hence, there is significance diff between etest, mba_p

# %% [markdown]
# ## 8. Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
### T_Test how significant the similarity between 2 groups
### different groups (Sci&Tech, Mkt&HR) same condition(salary)

from scipy.stats import ttest_ind
sci_tech=dataset[preprocessed_ds["degree_t"]=="Sci&Tech"]['salary']
MktHR=dataset[preprocessed_ds["specialisation"]=="Mkt&HR"]['salary']
print( sci_tech.isna().sum(), MktHR.isna().sum())
sci_tech=sci_tech.dropna()
MktHR=MktHR.dropna()
ttest_ind(sci_tech,MktHR)
# Out:
# 18 42
# TtestResult(statistic=np.float64(2.734391160944239), pvalue=np.float64(0.007496896218767113), df=np.float64(92.0))

# %%
# Decision based on Hypothesis testing...

## H0: There is no significnace difference between Sci&Tech, Mkt&HR
## H1: There is significance difference betwenn Sci&Tech, Mkt&HR

#if p<0.05 Reject Null hypothesis and accept Alternate hypothesis

## conclusion: p<.05 so Reject Null Hypothesis and Accept Alternate hypothesis.
##  There is significance differnece between Sci&Tech, Mkt&HR

# %% [markdown]
# # 9. Convert the normal distribution to standard normal distribution for salary column

# %%
import seaborn as sns
import matplotlib.pyplot as plot
from scipy.stats import norm

# %%
# Using distplot of seaborn
# parameters : kde: If True, a kernel density estimate is plotted on top of the histogram.
#              kde_kws: it gives you control over the appearance and behavior of the KDE line.

#sns.displot(data=preprocessed_ds["salary"],kde=True,kde_kws={"color":"blue"},color='green')

sns.histplot(data=preprocessed_ds["salary"], color='deepskyblue',stat='density')
sns.kdeplot(data=preprocessed_ds["salary"], color='red')
start_range=20000
end_range=80000
plot.axvline(start_range,color="green")
plot.axvline(end_range,color="green")

# calculate the paramerts: STD and MEAN for Normal distribution...
mean=preprocessed_ds["salary"].mean()
std=preprocessed_ds["salary"].std()
dist=norm(mean,std)

# %% [markdown]
#  # Z_Score:  Conversion of Normal Ditribution to Standard Normal Distribution....

# %%
def STD_Normal_Distribution(preprocessed_ds):
    import seaborn as sns
    from scipy.stats import zscore
    
    df=pd.DataFrame(preprocessed_ds)
    
    # Calculate the Zscore for each column and plot that points using histplot and kdeplot fns
    z_scores_df=df.apply(zscore)
    #sns.distplot(z_scores_df,kde=True)
    
    sns.histplot(data=z_scores_df, color='green',stat='density')
    sns.kdeplot(data=z_scores_df, color='red')
    
    #Display the Normal Distribution and STD Normal Distribution
    print("Original Normal Distribution:")
    print(df)
    print("STD Normal Distribution:")
    print(z_scores_df)

# %%
STD_Normal_Distribution(preprocessed_ds["salary"])
# Out:
# Original Normal Distribution:
#             salary
# 0    270000.000000
# 1    200000.000000
# 2    250000.000000
# 3    288655.405405
# 4    425000.000000
# ..             ...
# 210  400000.000000
# 211  275000.000000
# 212  295000.000000
# 213  204000.000000
# 214  288655.405405
#
# [215 rows x 1 columns]
# STD Normal Distribution:
#            salary
# 0   -2.414078e-01
# 1   -1.147234e+00
# 2   -5.002152e-01
# 3   -7.532285e-16
# 4    1.764349e+00
# ..            ...
# 210  1.440840e+00
# 211 -1.767060e-01
# 212  8.210139e-02
# 213 -1.095472e+00
# 214 -7.532285e-16
#
# [215 rows x 1 columns]

# %% [markdown]
# ## 10. What is the Probability Density Function(pdf) of the salary range from 700000 to 900000?

# %%
def pdf(preprocessed_ds,start_range,end_range):
    from scipy.stats import norm

    #start_range=70000
    #end_range=80000
    
    mean=preprocessed_ds["salary"].mean()
    std=preprocessed_ds["salary"].std()
    
    # calculate normal distribution using Mean and STD
    dist=norm(mean,std)
    
    # calculate the pdf using norm,pdf() from scipy.stats
    
    values=[]
    for value in range(start_range,end_range):
        values.append(value)
        
    probabilities=[]
    for value in values:
        probabilities.append(dist.pdf(value))
        
                             
    # sum the probabilites to find the area under the curve between the range
        prob=sum(probabilities)
    
    print("Area between range {},{}:{} ".format(start_range,end_range,prob))

# %%
pdf(preprocessed_ds,700000,900000)
# Out:
# Area between range 70000,80000:0.0011525816833325914

# %% [markdown]
# # 11. Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
### same group (degree_t(sci&tech))) diff condition (etest_p, mba_p)   - paired TTest
## Is etest_p and mba_p in Sci&Tech are same??? 
## TTest

from scipy.stats import ttest_ind

etest_p=preprocessed_ds[preprocessed_ds["degree_t"]=="Sci&Tech"]["etest_p"]
mba_p=  preprocessed_ds[preprocessed_ds["degree_t"]=="Sci&Tech"]["mba_p"]

ttest_ind(etest_p,mba_p)
# Out:
# TtestResult(statistic=np.float64(4.532000225151251), pvalue=np.float64(1.4289217003775638e-05), df=np.float64(116.0))

# %%
# Hypothesis Testing:
# H0- Null Hypothesis: There is NO significance similarity between etest_p and mba_p in Sci&Tech
# H1- Altertnate Hypothesis. There is significance similarity between etest_p and mba_p in Sci&Tech

# Conclusion:
# TtestResult(statistic=np.float64(4.532000225151251), pvalue=np.float64(1.4289217003775638e-05), df=np.float64(116.0))

# pvalue=np.float64(1.4289217003775638e-05), pvalue<.05. So Reject Null hypothesis and Accept Alternate hypothesis. 
# so there is significance similarity between etest_p and mba_p in Sci&Tech

# %% [markdown]
# # 12. Which parameter is highly correlated with salary

# %%
quan_table.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.051550
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.023571
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.054506
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.014148
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.152829
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.146324
# salary    0.051550  0.023571  0.054506 -0.014148  0.152829  0.146324  1.000000

# %%
# Heat Map
sns.heatmap(quan_table.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
## High correlation if r=0.95
## weak correaltion if r=0.54
### mba_p and etest_p - Low degree of porsitive correlation with salary

# %% [markdown]
# # 13. plot any useful graph and explain it.

# %%
# Heat Map (cmap: icefire, coolwarm, YlGnBu)
sns.heatmap(quan_table.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.boxplot(data=preprocessed_ds["salary"])
# Out:
# <Axes: ylabel='salary'>

# %%
preprocessed_ds.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   288655.405405
# std     77457.900102
# min    200000.000000
# 25%    250000.000000
# 50%    288655.405405
# 75%    288655.405405
# max    940000.000000

# %%
#Boxplot- for plotting the gender and salary field...

#sns.boxplot(data=preprocessed_ds,x="gender",y="salary", hue="specialisation",palette="YlGnBu")
sns.boxplot(data=preprocessed_ds,x="gender",y="salary",hue="gender",palette="YlGnBu")
# Out:
# <Axes: xlabel='gender', ylabel='salary'>

# %%
sns.boxplot(data=preprocessed_ds,x="specialisation",y="salary",hue="gender")
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sns.boxplot(data=preprocessed_ds,x="workex",y="salary",hue="gender")
# Out:
# <Axes: xlabel='workex', ylabel='salary'>
